# %% [markdown]
# <a href="https://colab.research.google.com/github/KARTHIKA-HALLIYARU-THIMMANNA/KARTHIKA-HALLIYARU-THIMMANNA/blob/main/courses/udacity_intro_to_tensorflow_for_deep_learning/l01c01_introduction_to_colab_and_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### Copyright 2018 The TensorFlow Authors.

# %% [markdown]
# # New Section

# %%
A=int(input())

if A%2==0:
  print("even")
else:
  print("odd")
# Out:
# 1234567890
# even
